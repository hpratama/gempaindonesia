# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('all_month.csv')
df
# Out:
#                           time   latitude   longitude    depth   mag magType  \
# 0     2018-02-05T03:34:19.450Z  33.497667 -116.785000    5.520  0.41      ml
# 1     2018-02-05T03:21:07.480Z  33.481667 -116.791167    4.260  1.45      ml
# 2     2018-02-05T03:13:53.390Z  40.046501 -122.904831    5.750  2.82      md
# 3     2018-02-05T03:06:20.790Z  33.490667 -116.788833    4.160  0.44      ml
# 4     2018-02-05T03:01:50.718Z  61.990700 -150.751900   58.300  1.90      ml
# 5     2018-02-05T02:54:16.970Z  38.822834 -122.798836    2.180  1.66      md
# 6     2018-02-05T02:46:31.900Z  33.678500 -116.794000   16.920  0.55      ml
# 7     2018-02-05T02:44:43.189Z  63.203300 -151.581100   11.700  2.70      ml
# 8     2018-02-05T02:40:25.620Z  38.820499 -122.795670    2.610  0.74      md
# 9     2018-02-05T02:39:00.070Z  56.423500 -148.574900   20.060  3.70      ml
# 10    2018-02-05T02:23:50.860Z  32.424000 -115.498333    2.560  1.50      ml
# ...

# %%
# Date vs magnitude

x = df['time']
y = df['mag']
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
gmp = pd.read_csv('gempa.txt', sep='\t+')
gmp.tail()
# Out:
# C:\Users\Hadyan Pratama\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#             Date        Time  Latitude  Longitude  Depth  Mag TypeMag   smaj  \
# 6321  2018-01-31  16:33:49.4     -9.59     116.35     10  3.6     MLv   5.66
# 6322  2018-01-31  19:55:03.5     -1.89     100.70     10  4.1     MLv  18.26
# 6323  2018-01-31  21:45:15.3     -9.33     113.89     12  3.6     MLv   3.62
# 6324  2018-01-31  22:04:03.9     -3.17     130.55     10  2.9     MLv   3.44
# 6325  2018-01-31  22:35:56.6     -8.20     117.64     19  4.2     MLv   7.05
#
#       smin   az    rms  cPhase                       Region
# 6321  1.00  233  0.234       9    Sumbawa Region, Indonesia
# 6322  0.77   71  0.754      18  Southern Sumatra, Indonesia
# ...

# %%
gmp['Date'] = pd.to_datetime(gmp['Date'])
gmp.tail()
# Out:
#            Date        Time  Latitude  Longitude  Depth  Mag TypeMag   smaj  \
# 6321 2018-01-31  16:33:49.4     -9.59     116.35     10  3.6     MLv   5.66
# 6322 2018-01-31  19:55:03.5     -1.89     100.70     10  4.1     MLv  18.26
# 6323 2018-01-31  21:45:15.3     -9.33     113.89     12  3.6     MLv   3.62
# 6324 2018-01-31  22:04:03.9     -3.17     130.55     10  2.9     MLv   3.44
# 6325 2018-01-31  22:35:56.6     -8.20     117.64     19  4.2     MLv   7.05
#
#       smin   az    rms  cPhase                       Region
# 6321  1.00  233  0.234       9    Sumbawa Region, Indonesia
# 6322  0.77   71  0.754      18  Southern Sumatra, Indonesia
# 6323  0.89  229  0.593      11     South of Java, Indonesia
# 6324  0.08  187  0.722       6             Seram, Indonesia
# 6325  0.64   92  0.430      17    Sumbawa Region, Indonesia

# %%
x = gmp['Date']
y = gmp['Mag']
plt.plot(x,y, 'ro')
plt.show()
