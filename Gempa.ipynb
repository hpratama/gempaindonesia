# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdates

# %%
#read data from csv
df = pd.read_csv('All (2).csv', parse_dates=['time'])
#set date as index
df.set_index('time')
df.tail()
# Out:
#                         time  latitude  longitude   depth  mag magType  nst  \
# 5857 2015-02-07 13:19:44.350    2.0882   127.4682   75.61  4.7      mb  NaN
# 5858 2015-02-07 11:09:09.500   -7.0841   129.2691  170.26  4.2      mb  NaN
# 5859 2015-02-07 05:26:31.000    2.0411   126.5206   35.00  4.3      mb  NaN
# 5860 2015-02-07 00:49:21.380    2.8062   128.3360  139.52  4.1      mb  NaN
# 5861 2015-02-07 00:26:04.240   -7.0137   129.4168  158.25  4.2      mb  NaN
#
#         gap   dmin   rms    ...                      updated  \
# 5857  139.0  1.311  0.97    ...     2015-05-04T22:47:46.040Z
# 5858   70.0  2.201  0.81    ...     2015-05-04T22:47:46.040Z
# 5859  159.0  1.518  1.16    ...     2015-05-04T22:47:46.040Z
# 5860  120.0  4.680  0.65    ...     2015-05-04T22:47:45.040Z
# 5861   86.0  2.099  1.02    ...     2015-05-04T22:47:45.040Z
#
#                                  place        type horizontalError depthError  \
# ...

# %%
# %matplotlib inline
#Plot depth vs mag
x = df['time']
y = df['mag']
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x,y,'ro')
plt.show()

# %%
gempa_besar = df[df.mag >= 6]
gempa_besar.tail()
# Out:
#                         time  latitude  longitude   depth  mag magType  nst  \
# 5293 2015-05-15 20:26:56.870   -2.5420   102.2191  151.00  6.0     mww  NaN
# 5629 2015-03-17 22:12:28.940    1.6686   126.5217   44.00  6.2     mww  NaN
# 5642 2015-03-15 23:17:16.910   -0.5409   122.3067   31.00  6.1     mww  NaN
# 5719 2015-03-03 10:37:30.050   -0.7789    98.7161   28.00  6.1     mww  NaN
# 5743 2015-02-27 13:45:05.370   -7.2968   122.5348  552.06  7.0     mww  NaN
#
#        gap   dmin   rms    ...                      updated  \
# 5293  25.0  2.503  1.15    ...     2016-11-10T21:47:31.852Z
# 5629  18.0  1.227  0.85    ...     2016-11-10T21:46:47.990Z
# 5642  16.0  0.681  1.02    ...     2016-11-10T21:46:46.368Z
# 5719  22.0  2.362  0.91    ...     2017-10-11T21:03:01.930Z
# 5743  12.0  1.362  1.12    ...     2017-11-14T16:13:18.218Z
#
#                                     place        type horizontalError  \
# 5293  105km ESE of Sungaipenuh, Indonesia  earthquake             3.1
# ...

# %%
# %matplotlib inline
y = gempa_besar['mag']
x = gempa_besar['time']
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x,y)
plt.show()

# %%
gempa_dangkal = df[df.depth <= 70]
gempa_dangkal.tail()
# Out:
#                         time  latitude  longitude  depth  mag magType  nst  \
# 5852 2015-02-08 13:59:57.580   -5.7920   130.7984  38.49  4.0      mb  NaN
# 5853 2015-02-07 21:42:01.140    0.7851    96.9081  10.00  4.1      mb  NaN
# 5854 2015-02-07 21:40:13.230    0.8358    96.8872  10.00  4.3      mb  NaN
# 5855 2015-02-07 18:53:25.520   -3.4372   135.6166  42.96  5.2      mb  NaN
# 5859 2015-02-07 05:26:31.000    2.0411   126.5206  35.00  4.3      mb  NaN
#
#         gap   dmin   rms    ...                      updated  \
# 5852  115.0  2.232  0.92    ...     2015-05-04T22:47:48.040Z
# 5853  193.0  0.843  0.64    ...     2015-05-04T22:47:47.040Z
# 5854  107.0  0.830  0.64    ...     2015-05-04T22:47:47.040Z
# 5855   18.0  3.401  0.78    ...     2015-05-04T22:47:47.040Z
# 5859  159.0  1.518  1.16    ...     2015-05-04T22:47:46.040Z
#
#                                  place        type horizontalError depthError  \
# ...

# %%
# %matplotlib inline
gempa_bahaya = df[df.mag >= 6][df.depth <= 70]
gempa_bahaya
# Out:
# C:\Users\Hadyan Pratama\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                         time  latitude  longitude  depth  mag magType  nst  \
# 45   2018-01-23 06:34:54.240   -7.1958   105.9181  43.91  6.0     mww  NaN
# 425  2017-10-31 11:50:48.370   -3.7449   127.7517   6.00  6.1     mww  NaN
# 700  2017-08-31 17:06:55.750   -1.1590    99.6881  43.14  6.3     mww  NaN
# 776  2017-08-13 03:08:10.560   -3.7682   101.6228  31.00  6.4     mww  NaN
# 1160 2017-05-29 14:35:21.510   -1.2923   120.4313  12.00  6.6     mww  NaN
# 1310 2017-04-28 20:23:17.260    5.5043   125.0658  26.00  6.9     mww  NaN
# 2060 2016-12-06 22:03:33.390    5.2834    96.1678  13.00  6.5     mww  NaN
# 2470 2016-09-17 01:20:17.940   -2.0829   140.5718   9.00  6.0     mww  NaN
# 2990 2016-06-09 04:13:08.130  -11.2487   116.2669  19.00  6.1     mww  NaN
# ...

# %%
# %matplotlib inline
x = gempa_besar['mag']
y = gempa_besar['depth']
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x,y,'ro')
plt.show()

# %%
# %matplotlib inline
x = gempa_besar['latitude']
y = gempa_besar['depth']
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x,y,'ro')
plt.show()

# %%
posisi = gempa_besar[['latitude','longitude']]
posisi.tail()
# Out:
#       latitude  longitude
# 5293   -2.5420   102.2191
# 5629    1.6686   126.5217
# 5642   -0.5409   122.3067
# 5719   -0.7789    98.7161
# 5743   -7.2968   122.5348

# %%
# %timeit posisi.to_csv('posisi.csv')
# Out:
# 2.24 ms ± 515 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %matplotlib inline
x = gempa_besar['longitude']
y = gempa_besar['depth']
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x,y,'ro')
plt.show()

# %%
import pandas as pd
gmp = pd.read_csv('gempa.txt', sep='\t+')
gmp.tail()
# Out:
# C:\Users\Hadyan Pratama\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#             Date        Time  Latitude  Longitude  Depth  Mag TypeMag   smaj  \
# 6321  2018-01-31  16:33:49.4     -9.59     116.35     10  3.6     MLv   5.66
# 6322  2018-01-31  19:55:03.5     -1.89     100.70     10  4.1     MLv  18.26
# 6323  2018-01-31  21:45:15.3     -9.33     113.89     12  3.6     MLv   3.62
# 6324  2018-01-31  22:04:03.9     -3.17     130.55     10  2.9     MLv   3.44
# 6325  2018-01-31  22:35:56.6     -8.20     117.64     19  4.2     MLv   7.05
#
#       smin   az    rms  cPhase                       Region
# 6321  1.00  233  0.234       9    Sumbawa Region, Indonesia
# 6322  0.77   71  0.754      18  Southern Sumatra, Indonesia
# ...

# %%
gmp['Date'] = pd.to_datetime(gmp['Date'])
gmp.tail()
# Out:
#            Date        Time  Latitude  Longitude  Depth  Mag TypeMag   smaj  \
# 6321 2018-01-31  16:33:49.4     -9.59     116.35     10  3.6     MLv   5.66
# 6322 2018-01-31  19:55:03.5     -1.89     100.70     10  4.1     MLv  18.26
# 6323 2018-01-31  21:45:15.3     -9.33     113.89     12  3.6     MLv   3.62
# 6324 2018-01-31  22:04:03.9     -3.17     130.55     10  2.9     MLv   3.44
# 6325 2018-01-31  22:35:56.6     -8.20     117.64     19  4.2     MLv   7.05
#
#       smin   az    rms  cPhase                       Region
# 6321  1.00  233  0.234       9    Sumbawa Region, Indonesia
# 6322  0.77   71  0.754      18  Southern Sumatra, Indonesia
# 6323  0.89  229  0.593      11     South of Java, Indonesia
# 6324  0.08  187  0.722       6             Seram, Indonesia
# 6325  0.64   92  0.430      17    Sumbawa Region, Indonesia

# %%
x = gmp['Date']
y = gmp['Mag']
fig, ax = plt.subplots(figsize=(15,7))
plt.plot(x,y,'ro')
plt.show()
